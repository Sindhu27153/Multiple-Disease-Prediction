# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
parkinsons_df = pd.read_csv("parkinsons - parkinsons.csv")

# %%
parkinsons_df.head(5)
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinsons_df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
parkinsons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
parkinsons_df.shape
# Out:
# (195, 24)

# %%
parkinsons_df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
#checking for null values
parkinsons_df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
import missingno as msno
msno.bar(parkinsons_df)
# Out:
# <Axes: >

# %%
parkinsons_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check status balance
plt.figure(figsize=(5, 4))
sns.histplot(data=parkinsons_df,x=parkinsons_df['status'], color="orange")
plt.title("Status Distribution (0 = Healthy, 1 = Need Treatment)")
plt.show()

# %%
# Drop non-numeric columns (if 'name' is present)
if 'name' in parkinsons_df.columns:
    parkinsons_df.drop(columns=['name'], inplace=True)

# %%
# Fundamental frequency vs status
plt.figure(figsize=(5, 4))
sns.boxplot(x='status',y='MDVP:Fo(Hz)', data=parkinsons_df, palette="coolwarm")
plt.title("Fundamental frequency vs Status")
plt.show()
# Out:
# C:\Users\sures\AppData\Local\Temp\ipykernel_22588\4040092865.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='status',y='MDVP:Fo(Hz)', data=parkinsons_df, palette="coolwarm")

# %%
# Fundamental  Higher frequency vs status
plt.figure(figsize=(5, 4))
sns.boxplot(x='status',y='MDVP:Fhi(Hz)', data=parkinsons_df, palette="coolwarm")
plt.title("Higher Fundamental frequency vs Status")
plt.show()
# Out:
# C:\Users\sures\AppData\Local\Temp\ipykernel_22588\2609250738.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='status',y='MDVP:Fhi(Hz)', data=parkinsons_df, palette="coolwarm")

# %%
# Fundamental frequency vs status
plt.figure(figsize=(5, 4))
sns.histplot(x='MDVP:Fhi(Hz)', data=parkinsons_df, palette="coolwarm",kde=True)
plt.title("Higher Fundamental frequency vs Status")
plt.show()
# Out:
# C:\Users\sures\AppData\Local\Temp\ipykernel_22588\132879021.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='MDVP:Fhi(Hz)', data=parkinsons_df, palette="coolwarm",kde=True)

# %%
# Fundamental lower frequency vs status
plt.figure(figsize=(5, 4))
sns.boxplot(x='status',y='MDVP:Flo(Hz)', data=parkinsons_df, palette="coolwarm")
plt.title(" Lower Fundamental frequency vs Status")
plt.show()
# Out:
# C:\Users\sures\AppData\Local\Temp\ipykernel_22588\3329440748.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='status',y='MDVP:Flo(Hz)', data=parkinsons_df, palette="coolwarm")

# %%
# jitter(%) vs status
plt.figure(figsize=(5, 4))
sns.scatterplot(x='status',y='MDVP:Jitter(%)',data=parkinsons_df, palette="coolwarm")
plt.title("MDVP(%jitter) vs Status")
plt.show()
# Out:
# C:\Users\sures\AppData\Local\Temp\ipykernel_22588\3404170110.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='status',y='MDVP:Jitter(%)',data=parkinsons_df, palette="coolwarm")

# %%
# MDVP:RAP vs status
plt.figure(figsize=(5, 4))
sns.scatterplot(x='status',y='MDVP:RAP',data=parkinsons_df, color="yellow")
plt.title("Relative Average Petrubation vs Status")
plt.show()

# %%
#NHR vs status
plt.figure(figsize=(5, 4))
sns.scatterplot(x='status',y='NHR', data=parkinsons_df, color="Green")
plt.title("Noise to Harmonics Ratio vs Status")
plt.show()

# %%
#NHR vs status
plt.figure(figsize=(5, 4))
sns.scatterplot(x='status',y='HNR', data=parkinsons_df,color="Green")
plt.title("Harmonics to Noise Ratio vs Status")
plt.show()

# %%
#Detrended Fluctuation Analysis
#NHR vs status
plt.figure(figsize=(5, 4))
sns.histplot(x='status',y='DFA', data=parkinsons_df, color="Green")
plt.title("Detrended Fluctuation Analysis vs Status")
plt.show()

# %%
#Pitch Period Entropy

plt.figure(figsize=(5, 4))
sns.histplot(x='status',y='PPE', data=parkinsons_df, color="Green")
plt.title("Pitch Period Entropy vs Status")
plt.show()

# %%
#NHR vs status
plt.figure(figsize=(5, 4))
sns.barplot(x='status',y='MDVP:Shimmer(dB)', data=parkinsons_df, color="Green")
plt.title("Shimmer(db) vs Status")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(parkinsons_df)
plt.title("outliers in dataset")
plt.xticks(rotation = 90)
plt.show()

# %%
# Iqr method to remove outliers
q1 = parkinsons_df.quantile(0.25)
q3 = parkinsons_df.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.8*iqr
upper_bound = q3 + 1.8 * iqr
parkinsons_df_no_outliers = parkinsons_df[~((parkinsons_df < lower_bound) | (parkinsons_df > upper_bound)).any(axis=1)]

# Print the number of removed outliers
print(f"Original dataset size: {parkinsons_df.shape[0]}")
print(f"New dataset size after outlier removal: {parkinsons_df_no_outliers.shape[0]}")
print(f"Total outliers removed: {parkinsons_df.shape[0] - parkinsons_df_no_outliers.shape[0]}")
# Out:
# Original dataset size: 195
# New dataset size after outlier removal: 122
# Total outliers removed: 73

# %%
# Correlation heatmap to find the relation between features
plt.figure(figsize=(12, 8))
sns.heatmap(parkinsons_df_no_outliers.corr(), cmap="coolwarm", annot=True)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Plot again after transformation
plt.figure(figsize=(12, 6))
sns.boxplot(data=parkinsons_df_no_outliers)
plt.xticks(rotation=90)
plt.title("After Removal of outliers")
plt.show()

# %%
#feature scaling to normalise the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
parkinsons_df["MDVP:Fo(Hz)"] = scaler.fit_transform(parkinsons_df[["MDVP:Fo(Hz)"]])
parkinsons_df["MDVP:Fhi(Hz)"] = scaler.fit_transform(parkinsons_df[["MDVP:Fhi(Hz)"]])
parkinsons_df["MDVP:Flo(Hz)"] = scaler.fit_transform(parkinsons_df[["MDVP:Flo(Hz)"]])
parkinsons_df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0      -0.829300     -0.436165     -0.952037         0.00784
# 1      -0.770972     -0.530974     -0.057721         0.00968
# 2      -0.909476     -0.723168     -0.109875         0.01050
# 3      -0.909622     -0.649092     -0.114229         0.00997
# 4      -0.925657     -0.606245     -0.130608         0.01284
# ..           ...           ...           ...             ...
# 190     0.483467      0.371185     -0.508265         0.00459
# 191     1.339202      0.612690     -0.618218         0.00564
# 192     0.495578      0.470104     -0.968393         0.01360
# 193     1.078761      2.190044     -0.954180         0.00740
# 194     1.454817      0.692246     -0.883481         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
parkinsons_df.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
#Feature Scaling 

x = parkinsons_df.drop(columns=['status'])
y = parkinsons_df['status']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
print(x_train)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 24      0.228355      0.040940     -0.910987         0.00742
# 0      -0.829300     -0.436165     -0.952037         0.00784
# 159    -0.637021     -0.639437     -0.095638         0.00605
# 5      -0.815735     -0.722609     -0.058458         0.00968
# 184    -0.905455      0.224061     -0.387509         0.00531
# ..           ...           ...           ...             ...
# 54     -1.100229     -0.684322     -0.309853         0.00761
# 110     1.125995      0.294522     -0.613657         0.00621
# 79     -1.294906     -0.892077     -0.709050         0.01038
# 67     -0.418073     -0.334199     -1.159203         0.00923
# 126    -0.389587      0.001458     -0.811124         0.00544
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 24            0.00005   0.00380   0.00390     0.01140       0.01659
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# ...

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score,roc_auc_score

parkinson_model = LogisticRegression()
parkinson_model.fit(x_train,y_train)
y_pred = parkinson_model.predict(x_test)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
auc = roc_auc_score(y_test,y_pred)
print(f"precision score: {precision}")
print(f"recall score:{recall}")
print(f"f1 score:{f1}")
print(f"roc_auc score:{auc}")
# Out:
# precision score: 0.8823529411764706
# recall score:0.9375
# f1 score:0.9090909090909091
# roc_auc score:0.6830357142857143
# d:\Multiple Disease Prediction\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score

parkinson_model = DecisionTreeClassifier(max_depth=2)
parkinson_model.fit(x_train,y_train)
y_pred = parkinson_model.predict(x_test)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
auc = roc_auc_score(y_test,y_pred)
print(f"precision score: {precision}")
print(f"recall score:{recall}")
print(f"f1 score:{f1}")
print(f"roc_auc score:{auc}")
# Out:
# precision score: 0.8888888888888888
# recall score:1.0
# f1 score:0.9411764705882353
# roc_auc score:0.7142857142857143

# %%
#Random Forest classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score

parkinson_model_A = RandomForestClassifier(n_estimators=100)
parkinson_model_A.fit(x_train,y_train)
y_pred = parkinson_model_A.predict(x_test)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
auc = roc_auc_score(y_test,y_pred)
print(f"precision score: {precision}")
print(f"recall score:{recall}")
print(f"f1 score:{f1}")
print(f"roc_auc score:{auc}")
# Out:
# precision score: 0.9393939393939394
# recall score:0.96875
# f1 score:0.9538461538461539
# roc_auc score:0.8415178571428571

# %%
#K Nearest Neignbors classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score, recall_score, f1_score

parkinson_model = KNeighborsClassifier()
parkinson_model.fit(x_train,y_train)
y_pred = parkinson_model.predict(x_test)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
auc = roc_auc_score(y_test,y_pred)
print(f"precision score: {precision}")
print(f"recall score:{recall}")
print(f"f1 score:{f1}")
print(f"roc_auc score:{auc}")
# Out:
# precision score: 0.8611111111111112
# recall score:0.96875
# f1 score:0.9117647058823529
# roc_auc score:0.6272321428571428

# %%
#Support Vector Classifier
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score

parkinson_model = KNeighborsClassifier()
parkinson_model.fit(x_train,y_train)
y_pred = parkinson_model.predict(x_test)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
auc = roc_auc_score(y_test,y_pred)
print(f"precision score: {precision}")
print(f"recall score:{recall}")
print(f"f1 score:{f1}")
print(f"roc_auc score:{auc}")
# Out:
# precision score: 0.8611111111111112
# recall score:0.96875
# f1 score:0.9117647058823529
# roc_auc score:0.6272321428571428

# %%
df = pd.DataFrame({
    "model" : ["logistic","Decision Tree","Random Forest","KNNeighbours","SVC"],
    "precision":[0.93,1.0,0.96,1.0,1.0],
    "recall":[0.88,0.88,0.88,0.96,0.96],
    "f1_score":[0.9,0.94,0.92,0.98,0.96],
    "AUC" : [0.74,0.94,0.81,0.98,0.98]
})

# %%
df
# Out:
#            model  precision  recall  f1_score   AUC
# 0       logistic       0.93    0.88      0.90  0.74
# 1  Decision Tree       1.00    0.88      0.94  0.94
# 2  Random Forest       0.96    0.88      0.92  0.81
# 3   KNNeighbours       1.00    0.96      0.98  0.98
# 4            SVC       1.00    0.96      0.96  0.98

# %%
#Decision Tree Classifier is a best model

# %%
import pickle

# Assuming 'model' is your trained model
with open('parkinson_model.pkl', 'wb') as file:
    pickle.dump(parkinson_model_A, file)
